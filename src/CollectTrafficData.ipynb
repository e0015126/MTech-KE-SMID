# %%
import requests

import json 
from xml.etree import ElementTree

# %% [markdown]
# ## DataMall@MyTransport
#
# - TrafficIncidents - every 2 minutes
# - TrafficSpeedBands - every 5 minutes
# - FaultyTrafficLights -every 2 minutes
#
# https://www.mytransport.sg/content/dam/mytransport/DataMall_StaticData/LTA_DataMall_API_User_Guide.pdf

# %%
if __name__=="__main__":
# Authentication parameters
 headers = { 'AccountKey' : 'uGRbgLzXR3ukHemzQGhomg==',
            'UniqueUserID' : '85f31f16-c935-471d-a599-e0e93e6a1070',
            'accept' : 'application/json'}

    
# Traffic Speed Bands
uri = 'http://datamall2.mytransport.sg/'
path_TSB = 'ltaodataservice/TrafficSpeedBands'
path_TI = 'ltaodataservice/TrafficIncidents'
path_FTL = 'ltaodataservice/FaultyTrafficLights'

# %% [markdown]
# In the TrafficSpeedBands API, we can determine Arterial road based upon the Road Category field:
#
# - A – Expressways
# - B – Major Arterial Roads
# - C – Arterial Roads
# - D – Minor Arterial Roads
# - E – Small Roads
# - F – Slip Roads
# - G – No category info available

# %%
r = requests.get(uri + path_TSB, headers=headers)
data = json.loads(r.text)
data
# Out:
# {u'odata.metadata': u'http://datamall2.mytransport.sg/ltaodataservice/$metadata#TrafficSpeedBands',
#  u'value': [{u'LinkID': u'103000000',
#    u'Location': u'1.3170142286123558 103.85298052044496 1.3166840028663076 103.85259882242372',
#    u'MaximumSpeed': 39,
#    u'MinimumSpeed': 20,
#    u'RoadCategory': u'E',
#    u'RoadName': u'KENT ROAD',
#    u'SpeedBand': 2},
#   {u'LinkID': u'103000010',
#    u'Location': u'1.3166507852203482 103.84102305136321 1.316912438354752 103.84022564204443',
#    u'MaximumSpeed': 19,
#    u'MinimumSpeed': 0,
#    u'RoadCategory': u'E',
#    u'RoadName': u'BUCKLEY ROAD',
#    u'SpeedBand': 1},
#   {u'LinkID': u'103000011',
#    u'Location': u'1.316912438354752 103.84022564204443 1.3166507852203482 103.84102305136321',
#    u'MaximumSpeed': 39,
#    u'MinimumSpeed': 20,
#    u'RoadCategory': u'E',
#    u'RoadName': u'BUCKLEY ROAD',
#    u'SpeedBand': 2},
#   {u'LinkID': u'103000014',
#    u'Location': u'1.3186726294030418 103.84700267615683 1.318021196845699 103.84711392225324',
#    u'MaximumSpeed': 59,
#    u'MinimumSpeed': 40,
#    u'RoadCategory': u'E',
#    u'RoadName': u'SHREWSBURY ROAD',
#    u'SpeedBand': 3},
#   {u'LinkID': u'103000015',
#    u'Location': u'1.318021196845699 103.84711392225324 1.3186726294030418 103.84700267615683',
#    u'MaximumSpeed': 59,
#    u'MinimumSpeed': 40,
#    u'RoadCategory': u'E',
#    u'RoadName': u'SHREWSBURY ROAD',
#    u'SpeedBand': 3},
#   {u'LinkID': u'103000018',
#    u'Location': u'1.3157770030138056 103.84426743639838 1.3159796416371992 103.84479180450104',
#    u'MaximumSpeed': 59,
#    u'MinimumSpeed': 40,
#    u'RoadCategory': u'E',
#    u'RoadName': u'JALAN KORMA',
#    u'SpeedBand': 3},
#   {u'LinkID': u'103000019',
#    u'Location': u'1.3159796416371992 103.84479180450104 1.3157770030138056 103.84426743639838',
#    u'MaximumSpeed': 59,
#    u'MinimumSpeed': 40,
#    u'RoadCategory': u'E',
#    u'RoadName': u'JALAN KORMA',
#    u'SpeedBand': 3},
#   {u'LinkID': u'103000022',
#    u'Location': u'1.3157638139947652 103.85346718361517 1.3159850985084538 103.8540099459191',
#    u'MaximumSpeed': 300,
#    u'MinimumSpeed': 60,
#    u'RoadCategory': u'E',
#    u'RoadName': u'SING AVENUE',
#    u'SpeedBand': 4},
#   {u'LinkID': u'103000023',
#    u'Location': u'1.3159850985084538 103.8540099459191 1.3157638139947652 103.85346718361517',
#    u'MaximumSpeed': 39,
#    u'MinimumSpeed': 20,
#    u'RoadCategory': u'E',
#    u'RoadName': u'SING AVENUE',
#    u'SpeedBand': 2},
#   {u'LinkID': u'103000026',
#    u'Location': u'1.3193495076454247 103.84576595796847 1.3193341115607338 103.84649970636899',
#    u'MaximumSpeed': 39,
#    u'MinimumSpeed': 20,
#    u'RoadCategory': u'E',
#    u'RoadName': u'MOULMEIN RISE',
#    u'SpeedBand': 2},
#   {u'LinkID': u'103000027',
#    u'Location': u'1.3193341115607338 103.84649970636899 1.3193495076454247 103.84576595796847',
#    u'MaximumSpeed': 39,
#    u'MinimumSpeed': 20,
#    u'RoadCategory': u'E',
#    u'RoadName': u'MOULMEIN RISE',
#    u'SpeedBand': 2},
#   {u'LinkID': u'103000030',
#    u'Location': u'1.3187614079491163 103.84584773223746 1.3184775003743368 103.845922903644',
#    u'MaximumSpeed': 59,
#    u'MinimumSpeed': 40,
#    u'RoadCategory': u'E',
#    u'RoadName': u'SINARAN DRIVE',
#    u'SpeedBand': 3},
#   {u'LinkID': u'103000031',
#    u'Location': u'1.3184775003743368 103.845922903644 1.3187614079491163 103.84584773223746',
#    u'MaximumSpeed': 39,
#    u'MinimumSpeed': 20,
#    u'RoadCategory': u'E',
#    u'RoadName': u'SINARAN DRIVE',
#    u'SpeedBand': 2},
#   {u'LinkID': u'103000034',
#    u'Location': u'1.3095165181658415 103.85444503278327 1.3102490949407017 103.85489147379481',
#    u'MaximumSpeed': 19,
#    u'MinimumSpeed': 0,
#    u'RoadCategory': u'E',
#    u'RoadName': u'LEMBU ROAD',
#    u'SpeedBand': 1},
#   {u'LinkID': u'103000035',
#    u'Location': u'1.3102490949407017 103.85489147379481 1.3095165181658415 103.85444503278327',
#    u'MaximumSpeed': 300,
#    u'MinimumSpeed': 60,
#    u'RoadCategory': u'E',
#    u'RoadName': u'LEMBU ROAD',
#    u'SpeedBand': 4},
#   {u'LinkID': u'103000036',
#    u'Location': u'1.3095165181658415 103.85444503278327 1.3098257335080767 103.85396567774879',
#    u'MaximumSpeed': 19,
#    u'MinimumSpeed': 0,
#    u'RoadCategory': u'E',
#    u'RoadName': u'DESKER ROAD',
#    u'SpeedBand': 1},
#   {u'LinkID': u'103000040',
#    u'Location': u'1.3094817613742067 103.85571657719505 1.3100415318076366 103.85617487784177',
#    u'MaximumSpeed': 39,
#    u'MinimumSpeed': 20,
#    u'RoadCategory': u'D',
#    u'RoadName': u'VERDUN ROAD',
#    u'SpeedBand': 2},
#   {u'LinkID': u'103000044',
#    u'Location': u'1.3102490949407017 103.85489147379481 1.3094817613742067 103.85571657719505',
#    u'MaximumSpeed': 39,
#    u'MinimumSpeed': 20,
#    u'RoadCategory': u'E',
#    u'RoadName': u'SYED ALWI ROAD',
#    u'SpeedBand': 2},
#   {u'LinkID': u'103000050',
#    u'Location': u'1.3040240949630044 103.82435328722222 1.3035181120546362 103.82439062361162',
#    u'MaximumSpeed': 39,
#    u'MinimumSpeed': 20,
#    u'RoadCategory': u'E',
#    u'RoadName': u'ORCHARD SPRING LANE',
#    u'SpeedBand': 2},
#   {u'LinkID': u'103000051',
#    u'Location': u'1.3035181120546362 103.82439062361162 1.3040240949630044 103.82435328722222',
#    u'MaximumSpeed': 39,
#    u'MinimumSpeed': 20,
#    u'RoadCategory': u'E',
#    u'RoadName': u'ORCHARD SPRING LANE',
#    u'SpeedBand': 2},
#   {u'LinkID': u'103000054',
#    u'Location': u'1.2977954689273836 103.81184137776128 1.2979363108403927 103.81139535719257',
#    u'MaximumSpeed': 19,
#    u'MinimumSpeed': 0,
#    u'RoadCategory': u'E',
#    u'RoadName': u'KAY SIANG ROAD',
#    u'SpeedBand': 1},
#   {u'LinkID': u'103000055',
#    u'Location': u'1.2979363108403927 103.81139535719257 1.2977954689273836 103.81184137776128',
#    u'MaximumSpeed': 19,
#    u'MinimumSpeed': 0,
#    u'RoadCategory': u'E',
#    u'RoadName': u'KAY SIANG ROAD',
#    u'SpeedBand': 1},
#   {u'LinkID': u'103000056',
#    u'Location': u'1.3235238431328136 103.8508428681823 1.3241924351833945 103.85149036161232',
#    u'MaximumSpeed': 39,
#    u'MinimumSpeed': 20,
#    u'RoadCategory': u'E',
#    u'RoadName': u'MARTABAN ROAD',
#    u'SpeedBand': 2},
#   {u'LinkID': u'103000062',
#    u'Location': u'1.3235238431328136 103.8508428681823 1.3242848711830488 103.85008775600016',
#    u'MaximumSpeed': 19,
#    u'MinimumSpeed': 0,
#    u'RoadCategory': u'E',
#    u'RoadName': u'MARTABAN ROAD',
#    u'SpeedBand': 1},
#   {u'LinkID': u'103000063',
#    u'Location': u'1.3242848711830488 103.85008775600016 1.3235238431328136 103.8508428681823',
#    u'MaximumSpeed': 39,
#    u'MinimumSpeed': 20,
#    u'RoadCategory': u'E',
#    u'RoadName': u'MARTABAN ROAD',
#    u'SpeedBand': 2},
#   {u'LinkID': u'103000066',
#    u'Location': u'1.319450709571759 103.84838600107199 1.3202305802943324 103.84823264087314',
#    u'MaximumSpeed': 39,
#    u'MinimumSpeed': 20,
#    u'RoadCategory': u'E',
#    u'RoadName': u'JALAN TAN TOCK SENG',
#    u'SpeedBand': 2},
#   {u'LinkID': u'103000067',
#    u'Location': u'1.3202305802943324 103.84823264087314 1.319450709571759 103.84838600107199',
#    u'MaximumSpeed': 39,
#    u'MinimumSpeed': 20,
#    u'RoadCategory': u'E',
#    u'RoadName': u'JALAN TAN TOCK SENG',
#    u'SpeedBand': 2},
#   {u'LinkID': u'103000068',
#    u'Location': u'1.3020505931348514 103.84753501033079 1.3020981908558338 103.8473568469501',
#    u'MaximumSpeed': 39,
#    u'MinimumSpeed': 20,
#    u'RoadCategory': u'E',
#    u'RoadName': u'SOPHIA ROAD',
#    u'SpeedBand': 2},
#   {u'LinkID': u'103000072',
#    u'Location': u'1.3020478491197238 103.85929118664532 1.3024623974822258 103.85961424505442',
#    u'MaximumSpeed': 39,
#    u'MinimumSpeed': 20,
#    u'RoadCategory': u'E',
#    u'RoadName': u'MUSCAT STREET',
#    u'SpeedBand': 2},
#   {u'LinkID': u'103000078',
#    u'Location': u'1.3479138498233316 103.6923894384768 1.3491170726830268 103.69342360283092',
#    u'MaximumSpeed': 300,
#    u'MinimumSpeed': 60,
#    u'RoadCategory': u'A',
#    u'RoadName': u'PAN ISLAND EXPRESSWAY',
#    u'SpeedBand': 4},
#   {u'LinkID': u'103000079',
#    u'Location': u'1.3491170726830268 103.69342360283092 1.3479138498233316 103.6923894384768',
#    u'MaximumSpeed': 300,
#    u'MinimumSpeed': 60,
#    u'RoadCategory': u'A',
#    u'RoadName': u'PAN ISLAND EXPRESSWAY',
#    u'SpeedBand': 4},
#   {u'LinkID': u'103000080',
#    u'Location': u'1.3436196253925365 103.78499221155269 1.3431444683048892 103.78388724345461',
#    u'MaximumSpeed': 300,
#    u'MinimumSpeed': 60,
#    u'RoadCategory': u'A',
#    u'RoadName': u'PAN ISLAND EXPRESSWAY',
#    u'SpeedBand': 4},
#   {u'LinkID': u'103000086',
#    u'Location': u'1.3009014346769388 103.90150591557894 1.3000155854751687 103.90006277560406',
#    u'MaximumSpeed': 39,
#    u'MinimumSpeed': 20,
#    u'RoadCategory': u'C',
#    u'RoadName': u'AMBER ROAD',
#    u'SpeedBand': 2},
#   {u'LinkID': u'103000087',
#    u'Location': u'1.3000155854751687 103.90006277560406 1.3009014346769388 103.90150591557894',
#    u'MaximumSpeed': 39,
#    u'MinimumSpeed': 20,
#    u'RoadCategory': u'C',
#    u'RoadName': u'AMBER ROAD',
#    u'SpeedBand': 2},
#   {u'LinkID': u'103000090',
#    u'Location': u'1.379554969889813 103.83982137005755 1.3778764702530613 103.83969577191468',
#    u'MaximumSpeed': 39,
#    u'MinimumSpeed': 20,
#    u'RoadCategory': u'C',
#    u'RoadName': u'ANG MO KIO AVENUE 4',
#    u'SpeedBand': 2},
#   {u'LinkID': u'103000091',
#    u'Location': u'1.3778764702530613 103.83969577191468 1.379554969889813 103.83982137005755',
#    u'MaximumSpeed': 59,
#    u'MinimumSpeed': 40,
#    u'RoadCategory': u'C',
#    u'RoadName': u'ANG MO KIO AVENUE 4',
#    u'SpeedBand': 3},
#   {u'LinkID': u'103000094',
#    u'Location': u'1.302018104115238 103.82687869301155 1.3025271007866848 103.82774617488766',
#    u'MaximumSpeed': 39,
#    u'MinimumSpeed': 20,
#    u'RoadCategory': u'E',
#    u'RoadName': u'JALAN TUPAI',
#    u'SpeedBand': 2},
#   {u'LinkID': u'103000095',
#    u'Location': u'1.3025271007866848 103.82774617488766 1.302018104115238 103.82687869301155',
#    u'MaximumSpeed': 39,
#    u'MinimumSpeed': 20,
#    u'RoadCategory': u'E',
#    u'RoadName': u'JALAN TUPAI',
#    u'SpeedBand': 2},
#   {u'LinkID': u'103000098',
#    u'Location': u'1.3034535281731428 103.82621354051224 1.302018104115238 103.82687869301155',
#    u'MaximumSpeed': 39,
#    u'MinimumSpeed': 20,
#    u'RoadCategory': u'D',
#    u'RoadName': u'TOMLINSON ROAD',
#    u'SpeedBand': 2},
#   {u'LinkID': u'103000099',
#    u'Location': u'1.302018104115238 103.82687869301155 1.3034535281731428 103.82621354051224',
#    u'MaximumSpeed': 39,
#    u'MinimumSpeed': 20,
#    u'RoadCategory': u'D',
#    u'RoadName': u'TOMLINSON ROAD',
#    u'SpeedBand': 2},
#   {u'LinkID': u'103000106',
#    u'Location': u'1.3185208604394962 103.8497306240015 1.318283897687114 103.84848967791835',
#    u'MaximumSpeed': 300,
#    u'MinimumSpeed': 60,
#    u'RoadCategory': u'E',
#    u'RoadName': u'SHREWSBURY ROAD',
#    u'SpeedBand': 4},
#   {u'LinkID': u'103000107',
#    u'Location': u'1.318283897687114 103.84848967791835 1.3185208604394962 103.8497306240015',
#    u'MaximumSpeed': 19,
#    u'MinimumSpeed': 0,
#    u'RoadCategory': u'E',
#    u'RoadName': u'SHREWSBURY ROAD',
#    u'SpeedBand': 1},
#   {u'LinkID': u'103000110',
#    u'Location': u'1.2771369059505562 103.81040355919788 1.277633353991097 103.80909264308315',
#    u'MaximumSpeed': 39,
#    u'MinimumSpeed': 20,
#    u'RoadCategory': u'D',
#    u'RoadName': u'TELOK BLANGAH HEIGHTS',
#    u'SpeedBand': 2},
#   {u'LinkID': u'103000111',
#    u'Location': u'1.277633353991097 103.80909264308315 1.2771369059505562 103.81040355919788',
#    u'MaximumSpeed': 39,
#    u'MinimumSpeed': 20,
#    u'RoadCategory': u'D',
#    u'RoadName': u'TELOK BLANGAH HEIGHTS',
#    u'SpeedBand': 2},
#   {u'LinkID': u'103000114',
#    u'Location': u'1.277633353991097 103.80909264308315 1.2780189431917124 103.80767112662544',
#    u'MaximumSpeed': 39,
#    u'MinimumSpeed': 20,
#    u'RoadCategory': u'D',
#    u'RoadName': u'TELOK BLANGAH HEIGHTS',
#    u'SpeedBand': 2},
#   {u'LinkID': u'103000115',
#    u'Location': u'1.2780189431917124 103.80767112662544 1.277633353991097 103.80909264308315',
#    u'MaximumSpeed': 39,
#    u'MinimumSpeed': 20,
#    u'RoadCategory': u'D',
#    u'RoadName': u'TELOK BLANGAH HEIGHTS',
#    u'SpeedBand': 2},
#   {u'LinkID': u'103000118',
#    u'Location': u'1.2765900388648779 103.81171237266507 1.276042945010033 103.81302172471231',
#    u'MaximumSpeed': 59,
#    u'MinimumSpeed': 40,
#    u'RoadCategory': u'D',
#    u'RoadName': u'TELOK BLANGAH HEIGHTS',
#    u'SpeedBand': 3},
#   {u'LinkID': u'103000119',
#    u'Location': u'1.276042945010033 103.81302172471231 1.2765900388648779 103.81171237266507',
#    u'MaximumSpeed': 59,
#    u'MinimumSpeed': 40,
#    u'RoadCategory': u'D',
#    u'RoadName': u'TELOK BLANGAH HEIGHTS',
#    u'SpeedBand': 3},
#   {u'LinkID': u'103000122',
#    u'Location': u'1.3504385286425702 103.69440891572472 1.3517801862142893 103.69536755921838',
#    u'MaximumSpeed': 300,
#    u'MinimumSpeed': 60,
#    u'RoadCategory': u'A',
#    u'RoadName': u'PAN ISLAND EXPRESSWAY',
#    u'SpeedBand': 4},
#   {u'LinkID': u'103000123',
#    u'Location': u'1.3517801862142893 103.69536755921838 1.3504385286425702 103.69440891572472',
#    u'MaximumSpeed': 300,
#    u'MinimumSpeed': 60,
#    u'RoadCategory': u'A',
#    u'RoadName': u'PAN ISLAND EXPRESSWAY',
#    u'SpeedBand': 4}]}

# %%
r = requests.get(uri + path_TI, headers=headers)
data = json.loads(r.text)
data
# Out:
# {u'odata.metadata': u'http://datamall2.mytransport.sg/ltaodataservice/$metadata#IncidentSet',
#  u'value': [{u'Latitude': 1.3132949525325222,
#    u'Longitude': 103.8746790805328,
#    u'Message': u'(16/10)21:14 Roadworks on Sims Avenue near Sims Way Junction.',
#    u'Type': u'Roadwork'},
#   {u'Latitude': 1.3219079058993926,
#    u'Longitude': 103.71346699577741,
#    u'Message': u'(16/10)21:11 Roadworks on AYE (towards Tuas) at Jurong Pier Rd Exit.',
#    u'Type': u'Roadwork'},
#   {u'Latitude': 1.4232086559980315,
#    u'Longitude': 103.75680458829095,
#    u'Message': u'(16/10)20:46 Roadworks on Woodlands Road (towards Woodlands Checkpoint) after Mandai Road. Avoid right lane.',
#    u'Type': u'Roadwork'},
#   {u'Latitude': 1.3192651175988297,
#    u'Longitude': 103.8532553781316,
#    u'Message': u'(16/10)20:42 Accident on Balestier Road (towards Moulmein Road) after CTE. Avoid left lane.',
#    u'Type': u'Accident'},
#   {u'Latitude': 1.423510466602605,
#    u'Longitude': 103.75727337271849,
#    u'Message': u'(16/10)20:36 Roadworks on Woodlands Road (towards City) after BKE. Avoid right lane.',
#    u'Type': u'Roadwork'},
#   {u'Latitude': 1.3274086367289972,
#    u'Longitude': 103.75722457777373,
#    u'Message': u'(16/10)20:27 Roadworks on Toh Tuck Avenue (towards Boon Lay Way) after Old Toh Tuck Road. Avoid left lane.',
#    u'Type': u'Roadwork'},
#   {u'Latitude': 1.426303109874252,
#    u'Longitude': 103.76283351120527,
#    u'Message': u'(16/10)20:20 Roadworks on Woodlands Road (towards City) after BKE. Avoid left lane.',
#    u'Type': u'Roadwork'},
#   {u'Latitude': 1.3546284784566585,
#    u'Longitude': 103.96357943250392,
#    u'Message': u'(16/10)20:15 Roadworks on TPE (towards SLE) before PIE Entrance. Avoid lane 1.',
#    u'Type': u'Roadwork'},
#   {u'Latitude': 1.329812486369671,
#    u'Longitude': 103.68484527052264,
#    u'Message': u'(16/10)20:00 Roadworks on Upper Jurong Road (towards City) after PIE. Avoid left lane.',
#    u'Type': u'Roadwork'},
#   {u'Latitude': 1.2990974155233554,
#    u'Longitude': 103.88536730361253,
#    u'Message': u'(16/10)15:54 Roadworks on Fort Road (towards Mountbatten Road) after Tanjong Rhu Road. Avoid left lane.',
#    u'Type': u'Roadwork'}]}

# %%
r = requests.get(uri + path_FTL, headers=headers)
data = json.loads(r.text)
data
# Out:
# {u'odata.metadata': u'http://datamall2.mytransport.sg/ltaodataservice/$metadata#FaultyTrafficLights',
#  u'value': []}

# %% [markdown]
# ## National Environment Agency - Environment APIs
#
# - 2 Hours Nowcast Dataset - refreshes hourly
# - Heavy Rain Warning - refreshes hourly
#
# https://www.nea.gov.sg/docs/default-source/api/developer's-guide.pdf

# %%
# 2 Hours Nowcast Dataset

url = 'http://api.nea.gov.sg/api/WebAPI/?dataset=2hr_nowcast&keyref=781CF461BB6606ADC767F3B357E848ED455313756293E581'
r = requests.get(url)
weather = ElementTree.fromstring(r.content)

# %%
weather[3][2].attrib['date'], weather[3][2].attrib['time'], weather[3][3].text
# Out:
# ('16-10-2016', '09:00 PM', '9.00 pm to 11.00 pm')

# %%
for area in weather[3][4]:
    print area.attrib['forecast'], area.attrib['name'], area.attrib['lat'], area.attrib['lon']
# Out:
# CL Ang Mo Kio 1.37500000 103.83900000
# CL Bedok 1.32100000 103.92400000
# CL Bishan 1.35077200 103.83900000
# CL Boon Lay 1.30400000 103.70100000
# CL Bukit Batok 1.35300000 103.75400000
# CL Bukit Merah 1.27700000 103.81900000
# CL Bukit Panjang 1.36200000 103.77195000
# CL Bukit Timah 1.32500000 103.79100000
# CL Central Water Catchment 1.38000000 103.80500000
# CL Changi 1.35700000 103.98700000
# CL Choa Chu Kang 1.37700000 103.74500000
# CL Clementi 1.31500000 103.76000000
# CL City 1.29200000 103.84400000
# CL Geylang 1.31800000 103.88400000
# CL Hougang 1.36121800 103.88600000
# CL Jalan Bahar 1.34700000 103.67000000
# CL Jurong East 1.32600000 103.73700000
# CL Jurong Island 1.26600000 103.69900000
# CL Jurong West 1.34039000 103.70500000
# CL Kallang 1.31200000 103.86200000
# CL Lim Chu Kang 1.42300000 103.71733200
# CL Mandai 1.41900000 103.81200000
# CL Marine Parade 1.29700000 103.89100000
# CL Novena 1.32700000 103.82600000
# CL Pasir Ris 1.37000000 103.94800000
# CL Paya Lebar 1.35800000 103.91400000
# CL Pioneer 1.31500000 103.67500000
# CL Pulau Tekong 1.40300000 104.05300000
# CL Pulau Ubin 1.40400000 103.96000000
# CL Punggol 1.40100000 103.90400000
# CL Queenstown 1.29100000 103.78576000
# CL Seletar 1.40400000 103.86900000
# CL Sembawang 1.44500000 103.81849500
# CL Sengkang 1.38400000 103.89144300
# CL Sentosa 1.24300000 103.83200000
# CL Serangoon 1.35700000 103.86500000
# CL Southern Islands 1.20800000 103.84200000
# CL Sungei Kadut 1.41300000 103.75600000
# CL Tampines 1.34500000 103.94400000
# CL Tanglin 1.30800000 103.81300000
# CL Tengah 1.37400000 103.71500000
# CL Toa Payoh 1.33430400 103.85632700
# CL Tuas 1.29494700 103.63500000
# CL Western Islands 1.20592600 103.74600000
# CL Western Water Catchment 1.40500000 103.68900000
# CL Woodlands 1.43200000 103.78652800
# CL Yishun 1.41800000 103.83900000

# %%
# Heavy Rain Warning

url = 'http://api.nea.gov.sg/api/WebAPI/?dataset=heavy_rain_warning&keyref=781CF461BB6606ADC767F3B357E848ED455313756293E581'
r = requests.get(url)
heavy_rain_warning = ElementTree.fromstring(r.content)
heavy_rain_warning[2][2].text
# Out:
# '\n   NIL\n  '
